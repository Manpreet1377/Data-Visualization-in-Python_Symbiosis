# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Specify the path to your CSV file
file_path = '/content/drive/My Drive/Data Visualisation in Python/RentPrediction.csv'

# %%
import pandas as pd
# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# %% [markdown]
# # Exploratory Data Analysis

# %%
#view the top 5 entries
df.head()
# Out:
#          id                                            name host_name  \
# 0   5728806                    Large private room in Nolita       Nat
# 1   2243769              Super Bowl New York City Apartment     Brian
# 2  35515415  COZY APT CLOSE TO LGA & JFK AND TRANSPORTATION     Jenny
# 3  36202006    Stream-Pressed Paradise (Laundry Room Setup)      Rita
# 4   3780951                       Charming Harlem apartment      Gina
#
#   neighbourhood_group    neighbourhood  latitude  longitude        room_type  \
# 0           Manhattan           Nolita  40.72217  -73.99481     Private room
# 1           Manhattan  Upper West Side  40.80020  -73.96045  Entire home/apt
# 2              Queens    East Elmhurst  40.75558  -73.89316  Entire home/apt
# 3       Staten Island          Concord  40.60110  -74.07830      Shared room
# 4           Manhattan           Harlem  40.81022  -73.94266      Shared room
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
#view the bottom 5 entries
df.tail()
# Out:
#              id                                               name  host_name  \
# 34221  28342248                                  Ridgewood retreat     Sophie
# 34222   8438775                Private BR & Bath near Central Park       Gabi
# 34223  27332770  Warm Home w/ Private Garden (Inwood Manhattan ...       Mary
# 34224   9063972                               Chill Bushwick Suite  Olu Bliss
# 34225  13372860  Cozy and simple Bedstuy studio right by the train     Ashton
#
#       neighbourhood_group       neighbourhood  latitude  longitude  \
# 34221              Queens           Ridgewood  40.70602  -73.90485
# 34222           Manhattan     Upper West Side  40.77697  -73.97698
# 34223           Manhattan              Inwood  40.86912  -73.92183
# 34224            Brooklyn            Bushwick  40.69709  -73.91435
# 34225            Brooklyn  Bedford-Stuyvesant  40.69076  -73.92886
#
#              room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
df['neighbourhood'].value_counts()
# Out:
# neighbourhood
# Williamsburg          2756
# Bedford-Stuyvesant    2577
# Harlem                1877
# Bushwick              1719
# Upper West Side       1403
#                       ...
# Richmondtown             1
# Spuyten Duyvil           1
# Lighthouse Hill          1
# Rossville                1
# Rosebank                 1
# Name: count, Length: 217, dtype: int64

# %%
#Overview of the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34226 entries, 0 to 34225
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              34226 non-null  int64
#  1   name                            34214 non-null  object
#  2   host_name                       34213 non-null  object
#  3   neighbourhood_group             34226 non-null  object
#  4   neighbourhood                   34226 non-null  object
#  5   latitude                        34226 non-null  float64
#  6   longitude                       34226 non-null  float64
#  7   room_type                       34226 non-null  object
#  8   price                           34226 non-null  int64
#  9   minimum_nights                  34226 non-null  int64
#  10  number_of_reviews               34226 non-null  int64
#  11  reviews_per_month               27244 non-null  float64
# ...

# %%
#Statistics of the columns
df.describe()
# Out:
#                  id      latitude     longitude         price  minimum_nights  \
# count  3.422600e+04  34226.000000  34226.000000  34226.000000    34226.000000
# mean   1.898209e+07     40.729059    -73.952070    153.480979        6.953690
# std    1.097597e+07      0.054604      0.046161    243.312608       20.255833
# min    2.595000e+03     40.499790    -74.244420      0.000000        1.000000
# 25%    9.460366e+06     40.690040    -73.983150     69.000000        1.000000
# 50%    1.965371e+07     40.722995    -73.955700    107.000000        2.000000
# 75%    2.908201e+07     40.763200    -73.935982    175.000000        5.000000
# max    3.648724e+07     40.913060    -73.712990  10000.000000     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       34226.000000       27244.000000                    34226.000000
# mean           23.390931           1.377074                        7.093905
# ...

# %%
#Different columns in the dataset
df.columns
# Out:
# Index(['id', 'name', 'host_name', 'neighbourhood_group', 'neighbourhood',
#        'latitude', 'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
#Size of the dataset
df.shape
# Out:
# (34226, 14)

# %%
#Null values in the dataset
df.isnull().sum()
# Out:
# id                                   0
# name                                12
# host_name                           13
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# reviews_per_month                 6982
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
#Unique categories in the categorical columns
df['neighbourhood_group'].unique()
# Out:
# array(['Manhattan', 'Queens', 'Staten Island', 'Brooklyn', 'Bronx'],
#       dtype=object)

# %%
df['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    17829
# Private room       15594
# Shared room          803
# Name: count, dtype: int64

# %%
#NUmber of unique categories in the column
df['neighbourhood_group'].nunique()
# Out:
# 5

# %%
#Function to find total values in each category
df['neighbourhood_group'].value_counts()
# Out:
# neighbourhood_group
# Manhattan        15193
# Brooklyn         14033
# Queens            3985
# Bronx              767
# Staten Island      248
# Name: count, dtype: int64

# %%
#Importing matplotlib library
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Plotting distribution of dataset based on neighbourhood_group

# %%
#Creating an axes instance
fig, ax = plt.subplots()

# %% [markdown]
# ## What is the distribution of the Neighbourhood_group?

# %%
# Create figure and axis (ax)
fig, ax = plt.subplots(figsize=(8, 6))  # Optional: Adjust the figure size

# Calculate value counts of neighbourhood_group
group_counts = df['neighbourhood_group'].value_counts()

# Plotting the bar chart with counts of each neighbourhood group using ax.bar
bars = ax.bar(group_counts.index, group_counts.values, color='skyblue')

# Adding labels and title
ax.set_xlabel('Neighbourhood Group')
ax.set_ylabel('Count')
ax.set_title('Count of Properties by Neighbourhood Group')

# Adding count numbers on top of each bar
for bar in bars:
    yval = bar.get_height()  # Get the height of the bar
    ax.text(bar.get_x() + bar.get_width() / 2, yval + 0.5, yval, ha='center', va='bottom')

# Display the plot
plt.show()

# %%
#View the current style of the graphs
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
#Use a different style referring to the documentation - (https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html)
plt.style.use('default')

# %% [markdown]
# ## What is the distribution of the room type? Percentage of availability?

# %%
# Calculate value counts of room_type
room_type_counts = df['room_type'].value_counts()

# Define labels and sizes for the pie chart
labels = room_type_counts.index
sizes = room_type_counts.values

# Plotting the pie chart
plt.figure(figsize=(4,4))  # Optional: Adjust the figure size
plt.pie(sizes, labels=labels, explode=(0.1, 0, 0), shadow=True, autopct='%1.1f%%', startangle=360)

# Adding a title


# Display the plot
plt.show()

# %% [markdown]
# ## Frequency of the Number of reviews?

# %%
# Extract the 'number_of_reviews' column
number_of_reviews = df['number_of_reviews']


# Plotting the histogram
plt.figure(figsize=(8, 6))  # Optional: Adjust the figure size
# Plot the histogram
n, bins, patches = plt.hist(number_of_reviews, bins=10, color='skyblue', edgecolor='black')

# Adding labels and title
plt.xlabel('Number of Reviews')
plt.ylabel('Frequency')
plt.title('Distribution of Number of Reviews')

# Adding count values on top of each bar
for i in range(len(patches)):
    x = bins[i] + (bins[i + 1] - bins[i]) / 2  # Calculate x-coordinate for placing text at the center of the bar
    y = n[i]  # Get the height of the bar (frequency)
    plt.text(x, y + 0.5, int(y), ha='center', va='bottom')

# Display the plot
plt.show()

# %% [markdown]
# ## Looking for outliers in the Prices

# %%
#Creating a Boxplot for finding outliers in Price
plt.figure(figsize = (30,10))
plt.boxplot(df['price'], vert= True)

#adding labels and title
plt.ylabel('Price')
plt.xlabel('Dollars')

#Display
plt.show()

# %% [markdown]
# ## Is there any correlation between number of reviews and the price?

# %%
# Plotting the scatter plot
plt.figure(figsize=(8, 6))  # Optional: Adjust the figure size
plt.scatter(df['number_of_reviews'], df['price'], color='skyblue')

# Adding labels and title
plt.xlabel('Number of reviews')
plt.ylabel('Price')
plt.title('Scatter Plot: Reviews vs Price')

# Display the plot
plt.show()

# %% [markdown]
# #### No correlation between Number of reviews and Price

# %% [markdown]
# ## Let's understand the importance of choosing the right plot

# %%
# Plotting the line plot
plt.figure(figsize=(8, 6))  # Optional: Adjust the figure size
plt.plot(df['number_of_reviews'], df['reviews_per_month'], marker='o', color='skyblue', linestyle='-', linewidth=2, markersize=1)

# Adding labels and title
plt.xlabel('Number of Reviews')
plt.ylabel('Reviews per Month')
plt.title('Line Plot: Number of Reviews vs Reviews per Month')

# Display the plot
plt.grid(False)  # Optional: Add grid lines
plt.show()

# %% [markdown]
# ## Plotting Neighbourhood Group Vs Room Type using CountPlot (Seaborn)

# %%
#Plotting countplot
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# Load the example flights dataset and convert to long-form
flights_long = sns.load_dataset("flights")
flights = (
    flights_long
    .pivot(index="month", columns="year", values="passengers")
)

# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# Load the example flights dataset and convert to long-form
flights_long = sns.load_dataset("flights")
flights = (
    flights_long
    .pivot(index="month", columns="year", values="passengers")
)

# Draw a heatmap with the numeric values in each cell

f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(
    df,
    x="number_of_reviews",
    palette="light:m_r",
    edgecolor=".3",
    linewidth=.5
)
# Out:
# <ipython-input-194-c4f0bac248d5>:8: UserWarning:
#
# Ignoring `palette` because no `hue` variable has been assigned.
# <Axes: xlabel='number_of_reviews', ylabel='Count'>

# %% [markdown]
# # Plotting using PLOTLY LIBRARY

# %%
import plotly.express as px

# %% [markdown]
# ## neighbourhood_group countplot

# %%
# Create a histogram to count occurrences of each neighbourhood_group
fig = px.histogram(df, x='neighbourhood_group', title='Countplot of Neighbourhood Groups')

# Customize layout (optional)
fig.update_layout(
    xaxis_title='Neighbourhood Group',
    yaxis_title='Count'
)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Calculate value counts of room_type
room_type_counts = df['room_type'].value_counts()

# Create a pie chart using Plotly Express
fig = px.pie(values=room_type_counts.values, names=room_type_counts.index, title='Distribution of Room Types', hole = 0.3, color_discrete_sequence=px.colors.sequential.RdBu)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Create a scatter plot
fig = px.scatter(
    df,
    x='number_of_reviews',
    y='price',
    title='Scatter Plot of Number of Reviews vs. Price',
    labels={'number_of_reviews': 'Number of Reviews', 'price': 'Price ($)'},
    color_discrete_sequence=['blue'],  # Set color of scatter points
    width=800,  # Set the width of the plot
    height=500  # Set the height of the plot
)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Plotting Latitude and Longitude

# %%
pip install geodatasets

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_name', 'neighbourhood_group', 'neighbourhood',
#        'latitude', 'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
from geodatasets import get_path

#Creating geodataframe

gdf = geopandas.GeoDataFrame(df, geometry=geopandas.points_from_xy(df.longitude, df.latitude))

# %% [markdown]
# ### On the world map

# %%
#Retrieving the world map data
world = geopandas.read_file(get_path("naturalearth.land"))

# Plot the world map
fig, ax = plt.subplots(figsize=(10, 6))  # Adjust figsize as needed
world.plot(ax=ax, color='white', edgecolor='black')

#Plotting our dataframe
gdf.plot(ax=ax, color="red")

#Display
plt.show()

# %% [markdown]
# ### On new york clip

# %%
#Get the world map
world = geopandas.read_file(get_path("naturalearth.land"))

# We restrict to New York.
ax = world.clip([-74.28, 40.49, -73.69, 40.92]).plot(color="white", edgecolor="black")

# We can now plot our ``GeoDataFrame``.
gdf.plot(ax=ax, color="red")

#Display
plt.show()
